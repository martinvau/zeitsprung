# %%
import requests
import bs4
import re
import pandas as pd

# %%
data = [
        {'EPISODE_NUM': '', 
         'EPISODE_NAME': '', 
         'HOST_NAME':'',
         'START_YEAR': '',
         'END_YEAR': '',
         'START_MONTH': '',
         'END_MONTH': '',
         'MAIN_COUNTRY': '',
         'MAIN_CITY': '',
         'COORD_LAT': '',
         'COORD_LONG': '',
         'COORD_ID': ''
        }]

# %%
result = requests.get("https://www.zeitsprung.fm/podcast/zs122/")
result.encoding = 'utf-8'
soup = bs4.BeautifulSoup(result.text,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="de-DE">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    ZS122: Die Belagerung von Masada - Zeitsprung
#   </title>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
#    <link href="https://www.zeitsprung.fm/podcast/zs122/" rel="canonical">
#     <meta content="de_DE" property="og:locale">
#      <meta content="article" property="og:type"/>
#      <meta content="ZS122: Die Belagerung von Masada - Zeitsprung" property="og:title"/>
#      <meta content="Wir springen in dieser Episode ins 1. Jahrhundert n.d.Zw.. Ort des Geschehens ist die Provinz Judäa. Die römische Provinz ist instabil und nach einem eigentlich kleinen Steuerprotest, entladen sich die Spannungen in einem Aufstand, der als der Große Jüdische Krieg in die Geschichte eingehen sollte. Wir sprechen über den Schlusspunkt dieser Auseinandersetzung, die auch heute noch symbolträchtige Belagerung der Festung Masada." property="og:description"/>
#      <meta content="https://www.zeitsprung.fm/podcast/zs122/" property="og:url"/>
#      <meta content="Zeitsprung" property="og:site_name"/>
#      <meta content="http://facebook.com/zeitsprung.fm" property="article:publisher"/>
#      <meta content="summary_large_image" name="twitter:card"/>
#      <meta content="@zeitsprungFM" name="twitter:creator"/>
#      <meta content="@zeitsprungFM" name="twitter:site"/>
#      <script class="yoast-schema-graph" type="application/ld+json">
#       {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.zeitsprung.fm/#website","url":"https://www.zeitsprung.fm/","name":"Zeitsprung","description":"Seit f\u00fcnf Jahren erz\u00e4hlen sich die Historiker Daniel Me\u00dfner und Richard Hemmer Woche f\u00fcr Woche eine Geschichte aus der Geschichte. Das Besondere daran: der eine wei\u00df nie, was der andere ihm erz\u00e4hlen wird. Dabei geht es um vergessene Ereignisse, au\u00dfergew\u00f6hnliche Pers\u00f6nlichkeiten und \u00fcberraschende Zusammenh\u00e4nge der Geschichte aus allen Epochen.","potentialAction":[{"@type":"SearchAction","target":"https://www.zeitsprung.fm/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"de-DE"},{"@type":"WebPage","@id":"https://www.zeitsprung.fm/podcast/zs122/#webpage","url":"https://www.zeitsprung.fm/podcast/zs122/","name":"ZS122: Die Belagerung von Masada - Zeitsprung","isPartOf":{"@id":"https://www.zeitsprung.fm/#website"},"datePublished":"2018-01-24T09:43:25+00:00","dateModified":"2018-01-24T09:43:25+00:00","inLanguage":"de-DE","potentialAction":[{"@type":"ReadAction","target":["https://www.zeitsprung.fm/podcast/zs122/"]}]}]}
#      </script>
#      <link href="//cdn.podlove.org" rel="dns-prefetch"/>
#      <link href="//s.w.org" rel="dns-prefetch"/>
#      <link href="//i0.wp.com" rel="dns-prefetch"/>
#      <link href="//i1.wp.com" rel="dns-prefetch"/>
#      <link href="//i2.wp.com" rel="dns-prefetch"/>
#      <link href="//c0.wp.com" rel="dns-prefetch"/>
#      <link href="https://www.zeitsprung.fm/feed/" rel="alternate" title="Zeitsprung » Feed" type="application/rss+xml"/>
#      <link href="https://www.zeitsprung.fm/comments/feed/" rel="alternate" title="Zeitsprung » Kommentar-Feed" type="application/rss+xml"/>
#      <link href="https://www.zeitsprung.fm/feed/mp3/" rel="alternate" title="Podcast Feed: Zeitsprung – Geschichten aus der Geschichte (mp3)" type="application/rss+xml"/>
#      <link href="https://www.zeitsprung.fm/feed/mp4/" rel="alternate" title="Podcast Feed: Zeitsprung – Geschichten aus der Geschichte (mp4)" type="application/rss+xml"/>
#      <link href="https://www.zeitsprung.fm/feed/ogg/" rel="alternate" title="Podcast Feed: Zeitsprung – Geschichten aus der Geschichte (ogg)" type="application/rss+xml"/>
#      <link href="https://www.zeitsprung.fm/feed/nospoilers/" rel="alternate" title="Podcast Feed: Zeitsprung – Geschichten aus der Geschichte (Zeitsprung No Spoilers)" type="application/rss+xml"/>
#      <link href="https://www.zeitsprung.fm/podcast/zs122/feed/" rel="alternate" title="Zeitsprung » ZS122: Die Belagerung von Masada Kommentar-Feed" type="application/rss+xml"/>
#      <script>
#       window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.zeitsprung.fm\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.5.1"}}; !function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
#      </script>
#      <style>
#       img.wp-smiley, img.emoji { display: inline !important; border: none !important; box-shadow: none !important; height: 1em !important; width: 1em !important; margin: 0 .07em !important; vertical-align: -0.1em !important; background: none !important; padding: 0 !important; }
#      </style>
#      <link href="https://www.zeitsprung.fm/wp-content/plugins/podlove-podcasting-plugin-for-wordpress/css/frontend.css?ver=1.0" id="podlove-frontend-css-css" media="all" rel="stylesheet"/>
#      <link href="https://www.zeitsprung.fm/wp-content/plugins/podlove-podcasting-plugin-for-wordpress/css/admin-font.css?ver=3.1.0" id="podlove-admin-font-css" media="all" rel="stylesheet"/>
#      <link href="https://c0.wp.com/c/5.5.1/wp-includes/css/dist/block-library/style.min.css" id="wp-block-library-css" media="all" rel="stylesheet"/>
#      <style id="wp-block-library-inline-css">
#       .has-text-align-justify{text-align:justify;}
#      </style>
#      <link href="https://www.zeitsprung.fm/wp-content/plugins/cookie-law-info/public/css/cookie-law-info-public.css?ver=1.9.1" id="cookie-law-info-css" media="all" rel="stylesheet"/>
#      <link href="https://www.zeitsprung.fm/wp-content/plugins/cookie-law-info/public/css/cookie-law-info-gdpr.css?ver=1.9.1" id="cookie-law-info-gdpr-css" media="all" rel="stylesheet"/>
#      <link href="https://www.zeitsprung.fm/wp-content/themes/twentytwenty/style.css?ver=1.3" id="twentytwenty-style-css" media="all" rel="stylesheet"/>
#      <style id="twentytwenty-style-inline-css">
#       .color-accent,.color-accent-hover:hover,.color-accent-hover:focus,:root .has-accent-color,.has-drop-cap:not(:focus):first-letter,.wp-block-button.is-style-outline,a { color: #cd2653; }blockquote,.border-color-accent,.border-color-accent-hover:hover,.border-color-accent-hover:focus { border-color: #cd2653; }button:not(.toggle),.button,.faux-button,.wp-block-button__link,.wp-block-file .wp-block-file__button,input[type="button"],input[type="reset"],input[type="submit"],.bg-accent,.bg-accent-hover:hover,.bg-accent-hover:focus,:root .has-accent-background-color,.comment-reply-link { background-color: #cd2653; }.fill-children-accent,.fill-children-accent * { fill: #cd2653; }body,.entry-title a,:root .has-primary-color { color: #000000; }:root .has-primary-background-color { background-color: #000000; }cite,figcaption,.wp-caption-text,.post-meta,.entry-content .wp-block-archives li,.entry-content .wp-block-categories li,.entry-content .wp-block-latest-posts li,.wp-block-latest-comments__comment-date,.wp-block-latest-posts__post-date,.wp-block-embed figcaption,.wp-block-image figcaption,.wp-block-pullquote cite,.comment-metadata,.comment-respond .comment-notes,.comment-respond .logged-in-as,.pagination .dots,.entry-content hr:not(.has-background),hr.styled-separator,:root .has-secondary-color { color: #6d6d6d; }:root .has-secondary-background-color { background-color: #6d6d6d; }pre,fieldset,input,textarea,table,table *,hr { border-color: #dcd7ca; }caption,code,code,kbd,samp,.wp-block-table.is-style-stripes tbody tr:nth-child(odd),:root .has-subtle-background-background-color { background-color: #dcd7ca; }.wp-block-table.is-style-stripes { border-bottom-color: #dcd7ca; }.wp-block-latest-posts.is-grid li { border-top-color: #dcd7ca; }:root .has-subtle-background-color { color: #dcd7ca; }body:not(.overlay-header) .primary-menu > li > a,body:not(.overlay-header) .primary-menu > li > .icon,.modal-menu a,.footer-menu a, .footer-widgets a,#site-footer .wp-block-button.is-style-outline,.wp-block-pullquote:before,.singular:not(.overlay-header) .entry-header a,.archive-header a,.header-footer-group .color-accent,.header-footer-group .color-accent-hover:hover { color: #cd2653; }.social-icons a,#site-footer button:not(.toggle),#site-footer .button,#site-footer .faux-button,#site-footer .wp-block-button__link,#site-footer .wp-block-file__button,#site-footer input[type="button"],#site-footer input[type="reset"],#site-footer input[type="submit"] { background-color: #cd2653; }.header-footer-group,body:not(.overlay-header) #site-header .toggle,.menu-modal .toggle { color: #000000; }body:not(.overlay-header) .primary-menu ul { background-color: #000000; }body:not(.overlay-header) .primary-menu > li > ul:after { border-bottom-color: #000000; }body:not(.overlay-header) .primary-menu ul ul:after { border-left-color: #000000; }.site-description,body:not(.overlay-header) .toggle-inner .toggle-text,.widget .post-date,.widget .rss-date,.widget_archive li,.widget_categories li,.widget cite,.widget_pages li,.widget_meta li,.widget_nav_menu li,.powered-by-wordpress,.to-the-top,.singular .entry-header .post-meta,.singular:not(.overlay-header) .entry-header .post-meta a { color: #6d6d6d; }.header-footer-group pre,.header-footer-group fieldset,.header-footer-group input,.header-footer-group textarea,.header-footer-group table,.header-footer-group table *,.footer-nav-widgets-wrapper,#site-footer,.menu-modal nav *,.footer-widgets-outer-wrapper,.footer-top { border-color: #dcd7ca; }.header-footer-group table caption,body:not(.overlay-header) .header-inner .toggle-wrapper::before { background-color: #dcd7ca; } { clip: rect(1px, 1px, 1px, 1px); height: 1px; position: absolute; overflow: hidden; width: 1px; }
#      </style>
#      <link href="https://www.zeitsprung.fm/wp-content/themes/twentytwenty/print.css?ver=1.3" id="twentytwenty-print-style-css" media="print" rel="stylesheet"/>
#      <link href="https://c0.wp.com/p/jetpack/9.0.2/modules/theme-tools/compat/twentytwenty.css" id="twentytwenty-jetpack-css" media="all" rel="stylesheet"/>
#      <link href="https://c0.wp.com/p/jetpack/9.0.2/css/jetpack.css" id="jetpack_css-css" media="all" rel="stylesheet"/>
#      <script>
#       if (document.location.protocol != "https:") {document.location = document.URL.replace(/^http:/i, "https:");}
#      </script>
#      <script id="jquery-core-js" src="https://c0.wp.com/c/5.5.1/wp-includes/js/jquery/jquery.js">
#      </script>
#      <script id="cookie-law-info-js-extra">
#       var Cli_Data = {"nn_cookie_ids":[],"cookielist":[],"ccpaEnabled":"","ccpaRegionBased":"","ccpaBarEnabled":"","ccpaType":"gdpr","js_blocking":"","custom_integration":"","triggerDomRefresh":""}; var cli_cookiebar_settings = {"animate_speed_hide":"500","animate_speed_show":"500","background":"#fff","border":"#444","border_on":"","button_1_button_colour":"#000","button_1_button_hover":"#000000","button_1_link_colour":"#fff","button_1_as_button":"1","button_1_new_win":"","button_2_button_colour":"#333","button_2_button_hover":"#292929","button_2_link_colour":"#444","button_2_as_button":"","button_2_hidebar":"1","button_3_button_colour":"#000","button_3_button_hover":"#000000","button_3_link_colour":"#fff","button_3_as_button":"1","button_3_new_win":"","button_4_button_colour":"#000","button_4_button_hover":"#000000","button_4_link_colour":"#fff","button_4_as_button":"1","font_family":"inherit","header_fix":"","notify_animate_hide":"1","notify_animate_show":"","notify_div_id":"#cookie-law-info-bar","notify_position_horizontal":"right","notify_position_vertical":"bottom","scroll_close":"","scroll_close_reload":"","accept_close_reload":"","reject_close_reload":"","showagain_tab":"","showagain_background":"#fff","showagain_border":"#000","showagain_div_id":"#cookie-law-info-again","showagain_x_position":"100px","text":"#000","show_once_yn":"","show_once":"10000","logging_on":"","as_popup":"","popup_overlay":"1","bar_heading_text":"","cookie_bar_as":"banner","popup_showagain_position":"bottom-right","widget_position":"left"}; var log_object = {"ajax_url":"https:\/\/www.zeitsprung.fm\/wp-admin\/admin-ajax.php"};
#      </script>
#      <script id="cookie-law-info-js" src="https://www.zeitsprung.fm/wp-content/plugins/cookie-law-info/public/js/cookie-law-info-public.js?ver=1.9.1">
#      </script>
#      <script id="podlove_frontend-js" src="https://www.zeitsprung.fm/wp-content/plugins/podlove-podcasting-plugin-for-wordpress/js/frontend.js?ver=3.1.0">
#      </script>
#      <script id="podlove-web-player-player-js" src="https://cdn.podlove.org/web-player/5.x/embed.js?ver=5.2.9">
#      </script>
#      <script async="" id="twentytwenty-js-js" src="https://www.zeitsprung.fm/wp-content/themes/twentytwenty/assets/js/index.js?ver=1.3">
#      </script>
#      <link href="https://www.zeitsprung.fm/wp-json/" rel="https://api.w.org/"/>
#      <link href="https://www.zeitsprung.fm/wp-json/wp/v2/episodes/1552" rel="alternate" type="application/json"/>
#      <link href="https://www.zeitsprung.fm/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#      <link href="https://www.zeitsprung.fm/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#      <meta content="WordPress 5.5.1" name="generator"/>
#      <link href="https://www.zeitsprung.fm/?p=1552" rel="shortlink"/>
#      <link href="https://www.zeitsprung.fm/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.zeitsprung.fm%2Fpodcast%2Fzs122%2F" rel="alternate" type="application/json+oembed"/>
#      <link href="https://www.zeitsprung.fm/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.zeitsprung.fm%2Fpodcast%2Fzs122%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#      <link href="https://www.zeitsprung.fm/podcast/zs122/?service=podlove-oembed&amp;format=json" rel="alternate" title="ZS122: Die Belagerung von Masada oEmbed Profile" type="application/json+oembed"/>
#      <link href="https://www.zeitsprung.fm/podcast/zs122/?service=podlove-oembed&amp;format=xml" rel="alternate" title="ZS122: Die Belagerung von Masada oEmbed Profile" type="application/xml+oembed"/>
#      <style type="text/css">
#       img#wpstats{display:none}
#      </style>
#      <script>
#       document.documentElement.className = document.documentElement.className.replace( 'no-js', 'js' );
#      </script>
#      <style>
#       .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important;}
#      </style>
#      <meta content="summary" name="twitter:card"/>
#      <meta content="https://www.zeitsprung.fm/podcast/zs122/" name="twitter:url"/>
#      <meta content="ZS122: Die Belagerung von Masada" name="twitter:title"/>
#      <meta content="Wir springen in dieser Episode ins 1. Jahrhundert n.d.Zw.. Ort des Geschehens ist die Provinz Judäa. Die römische Provinz ist instabil und nach einem eigentlich kleinen Steuerprotest, entladen sich die Spannungen in einem Aufstand, der als der Große Jüdische Krieg in die Geschichte eingehen sollte.
#
# Wir sprechen über den Schlusspunkt dieser Auseinandersetzung, die auch heute noch symbolträchtige Belagerung der Festung Masada." name="twitter:description"/>
#      <meta content="https://www.zeitsprung.fm/wp-content/uploads/2018/01/ZS122Masada.jpg" name="twitter:image"/>
#      <link href="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/cropped-zs_signet_4C.png?fit=32%2C32&amp;ssl=1" rel="icon" sizes="32x32"/>
#      <link href="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/cropped-zs_signet_4C.png?fit=192%2C192&amp;ssl=1" rel="icon" sizes="192x192"/>
#      <link href="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/cropped-zs_signet_4C.png?fit=180%2C180&amp;ssl=1" rel="apple-touch-icon"/>
#      <meta content="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/cropped-zs_signet_4C.png?fit=270%2C270&amp;ssl=1" name="msapplication-TileImage"/>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body class="podcast-template-default single single-podcast postid-1552 wp-custom-logo wp-embed-responsive singular enable-search-modal missing-post-thumbnail has-single-pagination showing-comments show-avatars footer-top-visible" data-rsssl="1">
#   <a class="skip-link screen-reader-text" href="#site-content">
#    Direkt zum Inhalt wechseln
#   </a>
#   <header class="header-footer-group" id="site-header" role="banner">
#    <div class="header-inner section-inner">
#     <div class="header-titles-wrapper">
#      <button aria-expanded="false" class="toggle search-toggle mobile-search-toggle" data-set-focus=".search-modal .search-field" data-toggle-body-class="showing-search-modal" data-toggle-target=".search-modal">
#       <span class="toggle-inner">
#        <span class="toggle-icon">
#         <svg aria-hidden="true" class="svg-icon" focusable="false" height="23" role="img" viewbox="0 0 23 23" width="23" xmlns="http://www.w3.org/2000/svg">
#          <path d="M38.710696,48.0601792 L43,52.3494831 L41.3494831,54 L37.0601792,49.710696 C35.2632422,51.1481185 32.9839107,52.0076499 30.5038249,52.0076499 C24.7027226,52.0076499 20,47.3049272 20,41.5038249 C20,35.7027226 24.7027226,31 30.5038249,31 C36.3049272,31 41.0076499,35.7027226 41.0076499,41.5038249 C41.0076499,43.9839107 40.1481185,46.2632422 38.710696,48.0601792 Z M36.3875844,47.1716785 C37.8030221,45.7026647 38.6734666,43.7048964 38.6734666,41.5038249 C38.6734666,36.9918565 35.0157934,33.3341833 30.5038249,33.3341833 C25.9918565,33.3341833 22.3341833,36.9918565 22.3341833,41.5038249 C22.3341833,46.0157934 25.9918565,49.6734666 30.5038249,49.6734666 C32.7048964,49.6734666 34.7026647,48.8030221 36.1716785,47.3875844 C36.2023931,47.347638 36.2360451,47.3092237 36.2726343,47.2726343 C36.3092237,47.2360451 36.347638,47.2023931 36.3875844,47.1716785 Z" transform="translate(-20 -31)">
#          </path>
#         </svg>
#        </span>
#        <span class="toggle-text">
#         Suche
#        </span>
#       </span>
#      </button>
#      <div class="header-titles">
#       <div class="site-logo faux-heading">
#        <a class="custom-logo-link" href="https://www.zeitsprung.fm/" rel="home">
#         <img alt="Zeitsprung" class="custom-logo" data-attachment-id="598" data-comments-opened="1" data-image-description="" data-image-meta='{"aperture":"0","credit":"","camera":"","caption":"","created_timestamp":"0","copyright":"","focal_length":"0","iso":"0","shutter_speed":"0","title":"","orientation":"0"}' data-image-title="zeitsprung_claim" data-large-file="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?fit=580%2C187&amp;ssl=1" data-medium-file="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?fit=300%2C97&amp;ssl=1" data-orig-file="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?fit=1180%2C380&amp;ssl=1" data-orig-size="1180,380" data-permalink="https://www.zeitsprung.fm/zeitsprung_claim/" height="380" sizes="(max-width: 1180px) 100vw, 1180px" src="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?fit=1180%2C380&amp;ssl=1" srcset="https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?w=1180&amp;ssl=1 1180w, https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?resize=300%2C97&amp;ssl=1 300w, https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?resize=768%2C247&amp;ssl=1 768w, https://i1.wp.com/www.zeitsprung.fm/wp-content/uploads/2016/09/zeitsprung_claim.png?resize=1024%2C330&amp;ssl=1 1024w" width="1180"/>
#        </a>
#        <span class="screen-reader-text">
#         Zeitsprung
#        </span>
#       </div>
#       <div class="site-description">
#        Seit fünf Jahren erzählen sich die Historiker Daniel Meßner und Richard Hemmer Woche für Woche eine Geschichte aus der Geschichte. Das Besondere daran: der eine weiß nie, was der andere ihm erzählen wird. Dabei geht es um vergessene Ereignisse, außergewöhnliche Persönlichkeiten und überraschende Zusammenhänge der Geschichte aus allen Epochen.
#       </div>
#      </div>
#      <button aria-expanded="false" class="toggle nav-toggle mobile-nav-toggle" data-set-focus=".close-nav-toggle" data-toggle-body-class="showing-menu-modal" data-toggle-target=".menu-modal">
#       <span class="toggle-inner">
#        <span class="toggle-icon">
#         <svg aria-hidden="true" class="svg-icon" focusable="false" height="7" role="img" viewbox="0 0 26 7" width="26" xmlns="http://www.w3.org/2000/svg">
#          <path d="M332.5,45 C330.567003,45 329,43.4329966 329,41.5 C329,39.5670034 330.567003,38 332.5,38 C334.432997,38 336,39.5670034 336,41.5 C336,43.4329966 334.432997,45 332.5,45 Z M342,45 C340.067003,45 338.5,43.4329966 338.5,41.5 C338.5,39.5670034 340.067003,38 342,38 C343.932997,38 345.5,39.5670034 345.5,41.5 C345.5,43.4329966 343.932997,45 342,45 Z M351.5,45 C349.567003,45 348,43.4329966 348,41.5 C348,39.5670034 349.567003,38 351.5,38 C353.432997,38 355,39.5670034 355,41.5 C355,43.4329966 353.432997,45 351.5,45 Z" fill-rule="evenodd" transform="translate(-329 -38)">
#          </path>
#         </svg>
#        </span>
#        <span class="toggle-text">
#         Menü
#        </span>
#       </span>
#      </button>
#     </div>
#     <div class="header-navigation-wrapper">
#      <nav aria-label="Horizontal" class="primary-menu-wrapper" role="navigation">
#       <ul class="primary-menu reset-list-style">
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-614" id="menu-item-614">
#         <a href="https://www.zeitsprung.fm/">
#          Home
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-60" id="menu-item-60">
#         <a href="https://www.zeitsprung.fm/archiv/">
#          Archiv
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page current_page_parent menu-item-799" id="menu-item-799">
#         <a href="https://www.zeitsprung.fm/blog/">
#          Blog
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-61" id="menu-item-61">
#         <a href="https://www.zeitsprung.fm/ueber-zeitsprung/">
#          Über Zeitsprung
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-729" id="menu-item-729">
#         <a href="https://www.zeitsprung.fm/geschichtspodcasts/">
#          Geschichtspodcasts
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2539" id="menu-item-2539">
#         <a href="https://www.zeitsprung.fm/zeitsprung-karte/">
#          Zeitsprung-Karte
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2988" id="menu-item-2988">
#         <a href="https://www.zeitsprung.fm/ueber-zeitsprung/#spenden">
#          Unterstützen!
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2989" id="menu-item-2989">
#         <a href="https://www.zeitsprung.fm/feed/mp3/">
#          Podcast abonnieren (RSS)
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <div class="header-toggles hide-no-js">
#       <div class="toggle-wrapper search-toggle-wrapper">
#        <button aria-expanded="false" class="toggle search-toggle desktop-search-toggle" data-set-focus=".search-modal .search-field" data-toggle-body-class="showing-search-modal" data-toggle-target=".search-modal">
#         <span class="toggle-inner">
#          <svg aria-hidden="true" class="svg-icon" focusable="false" height="23" role="img" viewbox="0 0 23 23" width="23" xmlns="http://www.w3.org/2000/svg">
#           <path d="M38.710696,48.0601792 L43,52.3494831 L41.3494831,54 L37.0601792,49.710696 C35.2632422,51.1481185 32.9839107,52.0076499 30.5038249,52.0076499 C24.7027226,52.0076499 20,47.3049272 20,41.5038249 C20,35.7027226 24.7027226,31 30.5038249,31 C36.3049272,31 41.0076499,35.7027226 41.0076499,41.5038249 C41.0076499,43.9839107 40.1481185,46.2632422 38.710696,48.0601792 Z M36.3875844,47.1716785 C37.8030221,45.7026647 38.6734666,43.7048964 38.6734666,41.5038249 C38.6734666,36.9918565 35.0157934,33.3341833 30.5038249,33.3341833 C25.9918565,33.3341833 22.3341833,36.9918565 22.3341833,41.5038249 C22.3341833,46.0157934 25.9918565,49.6734666 30.5038249,49.6734666 C32.7048964,49.6734666 34.7026647,48.8030221 36.1716785,47.3875844 C36.2023931,47.347638 36.2360451,47.3092237 36.2726343,47.2726343 C36.3092237,47.2360451 36.347638,47.2023931 36.3875844,47.1716785 Z" transform="translate(-20 -31)">
#           </path>
#          </svg>
#          <span class="toggle-text">
#           Suche
#          </span>
#         </span>
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="search-modal cover-modal header-footer-group" data-modal-target-string=".search-modal">
#     <div class="search-modal-inner modal-inner">
#      <div class="section-inner">
#       <form action="https://www.zeitsprung.fm/" aria-label="Suche nach:" class="search-form" method="get" role="search">
#        <label for="search-form-1">
#         <span class="screen-reader-text">
#          Suche nach:
#         </span>
#         <input class="search-field" id="search-form-1" name="s" placeholder="Suche …" type="search" value=""/>
#        </label>
#        <input class="search-submit" type="submit" value="Suchen"/>
#       </form>
#       <button aria-expanded="false" class="toggle search-untoggle close-search-toggle fill-children-current-color" data-set-focus=".search-modal .search-field" data-toggle-body-class="showing-search-modal" data-toggle-target=".search-modal">
#        <span class="screen-reader-text">
#         Suche schließen
#        </span>
#        <svg aria-hidden="true" class="svg-icon" focusable="false" height="16" role="img" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#         <polygon fill="" fill-rule="evenodd" points="6.852 7.649 .399 1.195 1.445 .149 7.899 6.602 14.352 .149 15.399 1.195 8.945 7.649 15.399 14.102 14.352 15.149 7.899 8.695 1.445 15.149 .399 14.102">
#         </polygon>
#        </svg>
#       </button>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="menu-modal cover-modal header-footer-group" data-modal-target-string=".menu-modal">
#    <div class="menu-modal-inner modal-inner">
#     <div class="menu-wrapper section-inner">
#      <div class="menu-top">
#       <button aria-expanded="false" class="toggle close-nav-toggle fill-children-current-color" data-set-focus=".menu-modal" data-toggle-body-class="showing-menu-modal" data-toggle-target=".menu-modal">
#        <span class="toggle-text">
#         Menü schließen
#        </span>
#        <svg aria-hidden="true" class="svg-icon" focusable="false" height="16" role="img" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#         <polygon fill="" fill-rule="evenodd" points="6.852 7.649 .399 1.195 1.445 .149 7.899 6.602 14.352 .149 15.399 1.195 8.945 7.649 15.399 14.102 14.352 15.149 7.899 8.695 1.445 15.149 .399 14.102">
#         </polygon>
#        </svg>
#       </button>
#       <nav aria-label="Mobile" class="mobile-menu" role="navigation">
#        <ul class="modal-menu reset-list-style">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-614">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/">
#            Home
#           </a>
#          </div>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-60">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/archiv/">
#            Archiv
#           </a>
#          </div>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page current_page_parent menu-item-799">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/blog/">
#            Blog
#           </a>
#          </div>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-61">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/ueber-zeitsprung/">
#            Über Zeitsprung
#           </a>
#          </div>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-729">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/geschichtspodcasts/">
#            Geschichtspodcasts
#           </a>
#          </div>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2539">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/zeitsprung-karte/">
#            Zeitsprung-Karte
#           </a>
#          </div>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2988">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/ueber-zeitsprung/#spenden">
#            Unterstützen!
#           </a>
#          </div>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2989">
#          <div class="ancestor-wrapper">
#           <a href="https://www.zeitsprung.fm/feed/mp3/">
#            Podcast abonnieren (RSS)
#           </a>
#          </div>
#         </li>
#        </ul>
#       </nav>
#      </div>
#      <div class="menu-bottom">
#      </div>
#     </div>
#    </div>
#   </div>
#   <main id="site-content" role="main">
#    <article class="post-1552 podcast type-podcast status-publish hentry tag-antike tag-judaea tag-masada tag-roemisches-reich post" id="post-1552">
#     <header class="entry-header has-text-align-center header-footer-group">
#      <div class="entry-header-inner section-inner medium">
#       <h1 class="entry-title">
#        ZS122: Die Belagerung von Masada
#       </h1>
#       <div class="post-meta-wrapper post-meta-single post-meta-single-top">
#        <ul class="post-meta">
#         <li class="post-author meta-wrapper">
#          <span class="meta-icon">
#           <span class="screen-reader-text">
#            Beitragsautor
#           </span>
#           <svg aria-hidden="true" class="svg-icon" focusable="false" height="20" role="img" viewbox="0 0 18 20" width="18" xmlns="http://www.w3.org/2000/svg">
#            <path d="M18,19 C18,19.5522847 17.5522847,20 17,20 C16.4477153,20 16,19.5522847 16,19 L16,17 C16,15.3431458 14.6568542,14 13,14 L5,14 C3.34314575,14 2,15.3431458 2,17 L2,19 C2,19.5522847 1.55228475,20 1,20 C0.44771525,20 0,19.5522847 0,19 L0,17 C0,14.2385763 2.23857625,12 5,12 L13,12 C15.7614237,12 18,14.2385763 18,17 L18,19 Z M9,10 C6.23857625,10 4,7.76142375 4,5 C4,2.23857625 6.23857625,0 9,0 C11.7614237,0 14,2.23857625 14,5 C14,7.76142375 11.7614237,10 9,10 Z M9,8 C10.6568542,8 12,6.65685425 12,5 C12,3.34314575 10.6568542,2 9,2 C7.34314575,2 6,3.34314575 6,5 C6,6.65685425 7.34314575,8 9,8 Z" fill="">
#            </path>
#           </svg>
#          </span>
#          <span class="meta-text">
#           Von
#           <a href="https://www.zeitsprung.fm/author/richard/">
#            Richard
#           </a>
#          </span>
#         </li>
#         <li class="post-date meta-wrapper">
#          <span class="meta-icon">
#           <span class="screen-reader-text">
#            Beitragsdatum
#           </span>
#           <svg aria-hidden="true" class="svg-icon" focusable="false" height="19" role="img" viewbox="0 0 18 19" width="18" xmlns="http://www.w3.org/2000/svg">
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </header>
#     <div class="post-inner thin ">
#      <div class="entry-content">
#       <div class="podlove-web-player intrinsic-ignore" id="player-5f90b649a1819">
#        <root data-test="player--xl" style="max-width:950px;min-width:260px;">
#         <div class="tablet:px-6 tablet:pt-6 mobile:px-4 mobile:pt-4 flex flex-col">
#          <div class="flex-col items-center mobile:flex tablet:hidden">
#           <show-title class="text-sm">
#           </show-title>
#           <episode-title class="text-base mb-2">
#           </episode-title>
#           <subscribe-button class="mb-4 mobile:flex tablet:hidden">
#           </subscribe-button>
#           <poster class="rounded-sm w-48 shadow overflow-hidden">
#           </poster>
#           <divider class="w-full my-6">
#           </divider>
#          </div>
#          <div class="tablet:flex flex-grow">
#           <div class="w-64 mobile:hidden tablet:block tablet:mr-6">
#            <poster class="rounded-sm shadow overflow-hidden">
#            </poster>
#           </div>
#           <div class="w-full">
#            <div class="hidden tablet:block">
#             <show-title class="text-base">
#             </show-title>
#             <episode-title class="text-xl desktop:text-2xl">
#             </episode-title>
#             <divider class="w-full my-4">
#             </divider>
#            </div>
#            <div class="flex items-center justify-between">
#             <div class="block">
#              <play-state on="active">
#               <speed-control class="flex items-center">
#               </speed-control>
#              </play-state>
#             </div>
#             <div class="flex">
#              <play-state on="active">
#               <chapter-previous class="mx-2 block">
#               </chapter-previous>
#              </play-state>
#              <play-state on="active">
#               <step-backward class="mx-2 block">
#               </step-backward>
#              </play-state>
#              <play-button :label="$t('PLAYER.PLAY_EPISODE')" class="mx-2 block">
#              </play-button>
#              <play-state on="active">
#               <step-forward class="mx-2 block">
#               </step-forward>
#              </play-state>
#              <play-state on="active">
#               <chapter-next class="mx-2 block">
#               </chapter-next>
#              </play-state>
#             </div>
#             <div class="block">
#              <play-state on="active">
#               <volume-control class="flex items-center">
#               </volume-control>
#              </play-state>
#             </div>
#            </div>
#            <div class="flex w-full">
#             <progress-bar>
#             </progress-bar>
#            </div>
#            <div class="flex w-full -mt-2">
#             <div class="w-3/12 text-left">
#              <timer-current class="text-sm">
#              </timer-current>
#             </div>
#             <div class="w-6/12 text-center truncate">
#              <play-state on="active">
#               <current-chapter class="text-sm">
#               </current-chapter>
#              </play-state>
#             </div>
#             <div class="w-3/12 text-right">
#              <timer-duration class="text-sm">
#              </timer-duration>
#             </div>
#            </div>
#           </div>
#          </div>
#          <divider class="w-full mt-6 mb-3">
#          </divider>
#          <div class="flex justify-between">
#           <div class="flex mobile:w-full tablet:w-3/12 desktop:w-3/12 justify-between">
#            <tab-trigger tab="chapters">
#             <icon type="chapter">
#             </icon>
#            </tab-trigger>
#            <tab-trigger tab="transcripts">
#             <icon type="transcripts">
#             </icon>
#            </tab-trigger>
#            <tab-trigger tab="files">
#             <icon type="download">
#             </icon>
#            </tab-trigger>
#            <tab-trigger tab="playlist">
#             <icon type="playlist">
#             </icon>
#            </tab-trigger>
#            <tab-trigger tab="share">
#             <icon type="share">
#             </icon>
#            </tab-trigger>
#           </div>
#           <subscribe-button class="mt-1 mobile:hidden tablet:flex">
#           </subscribe-button>
#          </div>
#         </div>
#         <div class="w-full relative overflow-hidden">
#          <tab name="chapters">
#           <tab-chapters>
#           </tab-chapters>
#          </tab>
#          <tab name="transcripts">
#           <tab-transcripts>
#           </tab-transcripts>
#          </tab>
#          <tab name="files">
#           <tab-files>
#           </tab-files>
#          </tab>
#          <tab name="playlist">
#           <tab-playlist>
#           </tab-playlist>
#          </tab>
#          <tab name="share">
#           <tab-share>
#           </tab-share>
#          </tab>
#          <tab-overflow>
#          </tab-overflow>
#         </div>
#         <error>
#         </error>
#        </root>
#       </div>
#       <script>
#        document.addEventListener("DOMContentLoaded", function () { podlovePlayer("#player-5f90b649a1819", "https://www.zeitsprung.fm/wp-json/podlove-web-player/shortcode/publisher/1552", "https://www.zeitsprung.fm/wp-json/podlove-web-player/shortcode/config/default/theme/default/show/default"); });
#       </script>
#       <p>
#        Wir springen in dieser Episode ins 1. Jahrhundert n.d.Zw. Ort des Geschehens ist die Provinz Judäa. Die römische Provinz ist instabil und nach einem eigentlich kleinen Steuerprotest, entladen sich die Spannungen in einem Aufstand, der als der Große Jüdische Krieg in die Geschichte eingehen sollte.
#       </p>
#       <p>
#        Wir sprechen über den Schlusspunkt dieser Auseinandersetzung, die auch heute noch symbolträchtige Belagerung der Festung Masada.
#       </p>
#       <p>
#        Das Episodenbild zeigt
#        <a href="https://commons.wikimedia.org/wiki/File:Aerial_view_of_Masada_(Israel)_02.jpg">
#         Masada in der heutigen Form
#        </a>
#        , auf einem Foto von
#        <a href="https://commons.wikimedia.org/wiki/User:Godot13">
#         Andrew Shiva
#        </a>
#        (unter einer
#        <a href="https://creativecommons.org/licenses/by-sa/4.0/deed.en">
#         CC 4.0 Lizenz
#        </a>
#        ).
#       </p>
#       <p>
#        <strong>
#         Wer Zeitsprung unterstützen möchte: Wir freuen uns, wenn ihr den Podcast bei
#         <a href="https://itunes.apple.com/de/podcast/zeitsprung/id1044844618" rel="noopener noreferrer" target="_blank">
#          iTunes
#         </a>
#         rezensiert oder bewertet. Für alle jene, die kein iTunes verwenden, gibt’s die neue Podcastplattform
#         <a href="http://panoptikum.io">
#          Panoptikum
#         </a>
#         , auch dort könnt ihr
#         <a href="https://panoptikum.io/podcasts/84">
#          Zeitsprung
#         </a>
#         empfehlen, bewerten aber auch euer ganz eigenes PodcasthörerInneprofil erstellen.
#        </strong>
#       </p>
#       <p>
#        <strong>
#         Wir freuen uns auch immer, wenn ihr euren Freundinnen und Freunden, Kolleginnen und Kollegen oder sogar Nachbarinnen und Nachbarn von Zeitsprung erzählt!
#        </strong>
#       </p>
#       <p>
#       </p>
#       <h1>
#        Related Episodes
#       </h1>
#       <ul>
#        <li>
#         <a href="https://www.zeitsprung.fm/podcast/zs133/">
#          Alexios Komnenos und der Erste Kreuzzug
#         </a>
#        </li>
#        <li>
#         <a href="https://www.zeitsprung.fm/podcast/zs158/">
#          Al-Biruni und die erste Globalgeschichte
#         </a>
#        </li>
#       </ul>
#       <p>
#        <ul class="episode_download_list">
#         <li>
#          Download:
#         </li>
#         <li>
#          <a href="https://www.zeitsprung.fm/podlove/file/2418/s/download/c/buttonlist/ZS122.mp3">
#           MP3 Audio
#           <span class="size">
#            30 MB
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.zeitsprung.fm/podlove/file/2416/s/download/c/buttonlist/ZS122.m4a">
#           MPEG-4 AAC Audio
#           <span class="size">
#            23 MB
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.zeitsprung.fm/podlove/file/2417/s/download/c/buttonlist/ZS122.ogg">
#           Ogg Vorbis Audio
#           <span class="size">
#            29 MB
#           </span>
#          </a>
#         </li>
#        </ul>
#        <div style="clear: both">
#        </div>
#        <br/>
#        <div class="podlove-contributors-cards">
#        </div>
#        <style>
#         .podlove-contributors-cards { margin-bottom: 1rem; background: white; overflow: hidden; border-radius: 0.375rem; box-shadow: 0 1px 3px 0 rgba(0, 0, 0, 0.1), 0 1px 2px 0 rgba(0, 0, 0, 0.06); } .podlove-contributors-card { display: flex; align-items: center; padding: 1rem 1.5rem } .podlove-contributors-card-inner { display: flex; align-items: center; flex: 1 1 0; min-width: 0; } .podlove-contributors-card-avatar { width: 50px; height: 50px; border-radius: 0.25rem; overflow: hidden; flex-shrink: 0; } .podlove-contributors-card-person { flex: 1 1 0; min-width: 0; padding: 0 1rem; display: grid; grid-template-columns: repeat(2, minmax(0, 1fr)); gap: 1rem; } .podlove-contributors-card-person-details { color: #999 } .podlove-contributors-card-services { flex-wrap: wrap; display: flex; align-items: center; align-content: center; justify-content: flex-end; } .podlove-contributors-card-services-service { display: inline-block; flex-shrink: 0; padding-left: 0.5rem; text-decoration: none; box-shadow: none; }
#        </style>
#       </p>
#      </div>
#     </div>
#     <div class="section-inner">
#      <div class="post-meta-wrapper post-meta-single post-meta-single-bottom">
#       <ul class="post-meta">
#        <li class="post-tags meta-wrapper">
#         <span class="meta-icon">
#          <span class="screen-reader-text">
#           Schlagwörter
#          </span>
#          <svg aria-hidden="true" class="svg-icon" focusable="false" height="18" role="img" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#           <path d="M15.4496399,8.42490555 L8.66109799,1.63636364 L1.63636364,1.63636364 L1.63636364,8.66081885 L8.42522727,15.44178 C8.57869221,15.5954158 8.78693789,15.6817418 9.00409091,15.6817418 C9.22124393,15.6817418 9.42948961,15.5954158 9.58327627,15.4414581 L15.4486339,9.57610048 C15.7651495,9.25692435 15.7649133,8.74206554 15.4496399,8.42490555 Z M16.6084423,10.7304545 L10.7406818,16.59822 C10.280287,17.0591273 9.65554997,17.3181054 9.00409091,17.3181054 C8.35263185,17.3181054 7.72789481,17.0591273 7.26815877,16.5988788 L0.239976954,9.57887876 C0.0863319284,9.4254126 0,9.21716044 0,9 L0,0.818181818 C0,0.366312477 0.366312477,0 0.818181818,0 L9,0 C9.21699531,0 9.42510306,0.0862010512 9.57854191,0.239639906 L16.6084423,7.26954545 C17.5601275,8.22691012 17.5601275,9.77308988 16.6084423,10.7304545 Z M5,6 C4.44771525,6 4,5.55228475 4,5 C4,4.44771525 4.44771525,4 5,4 C5.55228475,4 6,4.44771525 6,5 C6,5.55228475 5.55228475,6 5,6 Z" fill="">
description
# Out:
# 'Wir springen in dieser Episode ins 1. Jahrhundert n.d.Zw. Ort des Geschehens ist die Provinz Judäa. Die römische Provinz ist instabil und nach einem eigentlich kleinen Steuerprotest, entladen sich die Spannungen in einem Aufstand, der als der Große Jüdische Krieg in die Geschichte eingehen sollte.'

# %%
img_str = soup.find_all('meta')[18]
img_url = re.findall(r'"([^"]*)"', str(img_str))[0]
img_url
# Out:
# 'https://www.zeitsprung.fm/wp-content/uploads/2018/01/ZS122Masada.jpg'

# %%
author_str = soup.find_all('span')[14]
author_name = re.findall(r'>([^"]*)</a', str(author_str))[0]
author_name
# Out:
# 'Richard'

# %%
tag_str = soup.find_all('a')
tag_list = re.findall(r'rel="tag">([^"]*)</a', str(tag_str))

# %%
pattern = r'"([A-Za-z0-9_\./\\-]*)"'
re.search(pattern, str(img_url))

# %%
author_str
# Out:
# <span class="meta-text"> Von <a href="https://www.zeitsprung.fm/author/richard/">Richard</a> </span>

# %%
re.findall(r'"([^"]*)"', str(img_url))[0]
# Out:
# 'https://www.zeitsprung.fm/wp-content/uploads/2018/01/ZS122Masada.jpg'

# %%
data= []


for i in range(1,265+1):
    
    title = ''
    author_name = ''
    tags = ''
    img_url = ''
    
    dummy = [{'EPISODE_NUM': '', 
         'EPISODE_NAME': '', 
         'AUTHOR':'',
         'START_YEAR': '',
         'END_YEAR': '',
         'START_MONTH': '',
         'END_MONTH': '',
         'MAIN_COUNTRY': '',
         'MAIN_CITY': '',
         'COORD_LAT': '',
         'COORD_LONG': '',
         'COORD_ID': '',
         'URL': '',
         'IMG_URL': '',
         'DESCRIPTION': '',
         'TAGS': ''
        }]

    
    
    if i < 10:
        num = '0'+str(i)
    else:
        num = str(i)

    
    # download site
    url = 'https://www.zeitsprung.fm/podcast/zs'+num+'/'
    result = requests.get(url)
    result.encoding = 'utf-8'
    soup = bs4.BeautifulSoup(result.text,"html.parser")
    
    #get info
    try:
        title = soup.select("title")[0].getText()
        title = re.findall(r':([^"]*) - Zeitsprung', str(title))[0]
        print(f">> {num}: {title}")
    except:
        print(f"\t ERROR: title download failed")
        title = ''
    finally:
        pass
    
    try:
        description = soup.p.getText()
    except:
        print(f"\t ERROR: description download failed")
        description = ''
    finally:
        pass
    
    try:
        #img_str = soup.find_all('meta')[18]
        #img_url = re.findall(r'"([^"]*)"', str(img_str))[0]
        
        img_str = soup.find_all('img')[11]
        img_url = re.findall(r'src="([^"]*)" style', str(img_str))
        print(img_url)
        
    except:
        print(f"\t ERROR: image url download failed")
        img_url = ''
    finally:
        pass
    
    try:
        author_str = soup.find_all('span')[14]
        author_name = re.findall(r'>([^"]*)</a', str(author_str))[0]
    except:
        print(f"\t ERROR: author name download failed")
        author_name = ''
    finally:
        pass
    
    try:
        tag_str = soup.find_all('a')
        tag_list = re.findall(r'rel="tag">([^"]*)</a', str(tag_str))
        tags = ','.join(map(str, tag_list))
    except:
        print(f"\t ERROR: author name download failed")
        tags = ''
    finally:
        pass
    

    
    dummy[0].update({'EPISODE_NUM': i})
    dummy[0].update({'EPISODE_NAME': title})
    dummy[0].update({'AUTHOR': author_name})
    dummy[0].update({'DESCRIPTION': description})
    dummy[0].update({'TAGS': tags})
    dummy[0].update({'IMG_URL': img_url})
    dummy[0].update({'URL': url})
    
    data.append(dummy[0])
    


        
    
    

df = pd.DataFrame(data) 

df.to_csv('../data/'+'dump.csv', sep='\t', encoding='utf-8',index=False)
# Out:
# >> 01:  Vier Langobarden-Könige und ein Trinkbecher
# []
# >> 02:  Tatortschau mit Wiedererkennungswert
# []
# >> 03:  Fitness-Parcours für den Pharao
# []
# >> 04:  Wellingtons Rache, oder: Ein Bein für ein Königreich
# []
# >> 05:  Lernen Sie Geschichte!
# []
# >> 06:  Ada und die Pferdewetten
# []
# >> 07:  Geteilte Habsburger
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 08:  Herr der Fliegen
# []
# >> 09:  Wer den englischen Parlamentsbrand auf dem Kerbholz hat
# []
# >> 10:  Craigslist in der Frühen Neuzeit
# []
# >> 11:  Von Kindern und Kegeln
# []
# >> 12:  Ein Kaiser, ein Gott, viele Todesfälle
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 13:  Ein Spionagefall erschüttert die Habsburger Monarchie
# []
# >> 14:  Ein englisches Atlantis
# []
# >> 15:  Das Mailüfterl
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 16:  Ton, Steine, Scherben oder wie Rom sich einen achten Hügel baute
# []
# >> 17:  Eine Urkunde, ein Zeltlager und eine Fälschung
# []
# >> 18:  Wie Russland den Bart verlor
# []
# >> 19:  Wenn ein Wissenschaftler an Drachen glaubt
# []
# >> 20:  Von Drachenknochen und Schildkrötenorakeln
# []
# >> 21:  Von der Erfindung der Einbauküche
# []
# >> 22:  Vom Goldjungen zum Staatsgefangenen
# []
# >> 23:  Ziemlich beste Feindschaft oder Die Anfänge der Bakteriologie
# []
# >> 24:  A French Connection, zum Scheitern verurteilt
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 25:  Eine kaiserliche Bibliothek des Menschengeschlechts
# []
# >> 26:  Wie der Champagner zu seinen Bläschen kam
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 27:  Die Rote Zora und ihre Vorfahren
# []
# >> 28:  Von Appenzellern, Bregenzern und einer Frau namens Guta
# []
# >> 29:  Ein Müller in den Fängen der Inquisition
# []
# >> 30:  Wie die Zeit zu unserer Zeit wurde
# []
# >> 31:  Blitzkrieg im Fußballstadion
# []
# >> 32:  Henry Gunther
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 33:  Curta – eine Rechenmaschine und ihre Geschichte
# []
# >> 34:  Tee, Silber und Rauschmittel
# []
# >> 35:  Magia Posthuma – Vampirismus in Zeiten der Aufklärung
# []
# >> 36:  Eine sehr kurze Geschichte des Deodorants
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 37:  Eine Reise um die Welt
# []
# >> 38:  Eine kurze Geschichte der Leibeigenschaft
# []
# >> 39:  Die Legion Erzengel Michael und Corneliu Codreanu
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 40:  Über den Ursprung der Seidenstraße
# []
# >> 41:  Der Wiener Kreis und die Ermordung von Moritz Schlick
# []
# >> 42:  The City of Roses – Ein Rosengarten für Portland
# []
# >> 43:  Josef Eisemann, Seiltänzer in Wien
# []
# >> 44:  Eine kurze Geschichte der Süßigkeiten
# []
# >> 45:  Zwentendorf – Das sicherste Kernkraftwerk der Welt
# []
# >> 46:  Aufstieg und Fall der Republik Ragusa
# []
# >> 47:  Die Schwabenkinder und ihre Geschichte
# []
# >> 48:  George Ansons katastrophale Expedition – und ihre Folgen
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 49:  Der »Dig Tree« und die erste Durchquerung Australiens
# []
# >> 50:  Ossian, ein altgälisches Epos wie keines davor
# []
# >> 51:  Eine kurze Geschichte der Rhythmologie und der Erforschung des Herzens
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# 	 ERROR: title download failed
# []
# >> 53:  Ein Verrat und ein langer Strich auf der Berliner Mauer
# []
# >> 54:  Die erste Rektorin einer deutschen Universität
# []
# >> 55:  Der letzte Kammerdiener des alten Kaisers
# []
# >> 56:  Piggly Wiggly und die Geschichte des Supermarkts
# []
# >> 57:  Von Grabtüchern, Knochen und wieder mal Venedig
# []
# >> 58:  Londoner Kutschenstreit
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 59:  The Lost Colony
# []
# >> 60:  Wie das Essengehen erfunden wurde
# []
# 	 ERROR: title download failed
# []
# >> 62:  Eine kurze Geschichte der Rollschuhe und des Rollschuhfahrens
# []
# >> 63:  Konstantin und die Janitscharen
# []
# >> 64:  Paul Dirac und die Schönheit der Mathematik
# []
# >> 65:  Die Erfindung des diamantenen Verlobungsrings
# []
# >> 66:  Der Aufstieg Hamburgs – Fake it 'til you make it
# []
# >> 67:  Palladio, der erfolgreichste Architekt aller Zeiten
# []
# >> 68:  Eine ganz kleine Geschichte der Mikroskopie
# []
# >> 69:  Die Boston Melasse Katastrophe
# []
# >> 70:  Die Würzburger Lügensteine
# []
# >> 71:  Wie die Kartoffel nach Europa kam (und alles veränderte)
# []
# >> 72:  Phantominseln
# []
# >> 73:  Ludwig XIV. und seine pikante Operation
# []
# >> 74:  Die Bonnot-Bande und die Erfindung des Fluchtautos
# []
# >> 75:  Sobhuza II., König von Swaziland
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 76:  Holdouts – Japans vergessene Soldaten
# []
# >> 77:  Der Augsburger Kalenderstreit: Folgen eines tatsächlichen Zeitsprungs
# []
# >> 78:  Eine kurze Geschichte der Sommerzeit
# []
# >> 79:  Das Rolandslied – über Heldentaten, Karl den Großen und Kreuzzugspropaganda
# []
# >> 80:  Eine Kirche auf dem Dachboden – Reformation und das Goldene Zeitalter in den Niederlanden
# []
# >> 81:  Eine kurze Geschichte des Essbestecks (aber ohne Löffel)
# []
# >> 82:  Victor Gruen und die Erfindung des Einkaufszentrums
# []
# >> 83:  100 Jahre vor der Reformation – Jan Hus und die Hussitenkriege
# []
# >> 84:  Eine kleine Geschichte des Klimas und des Klimawandels
# []
# >> 85:  Ein Arm, ein Hai, ein Kriminalfall
# []
# >> 86:  Sabbatai Zwi – Der falsche Messias
# []
# >> 87:  Die Einführung von Freigeld und das Wunder von Wörgl
# []
# >> 88:  Von der Tanzwut und ihrer (wahrscheinlichen) Ursache
# []
# >> 89:  Seelenkonskription – die Anfänge der modernen Volkszählungen
# []
# >> 90:  Aufstieg und Fall des Roger Casement
# []
# >> 91:  Jan van Eyck – Der König unter den Malern und die Erfindung des Gemäldes
# []
# >> 92:  Die Geschichte der Typhoid Mary
# []
# >> 93:  Das Geheimnis des Lebens – Wie es zur Entdeckung der Doppelhelix kam
# []
# >> 94:  Wer zittert nicht vor den Mohocks?
# []
# >> 95:  Der Aufstieg des Jakob Fugger
# []
# >> 96:  Von der Entstehung des Croissants und anderen kulinarischen Mythen
# []
# >> 97:  Neutral-Moresnet – Ein Niemandsland mitten in Europa
# []
# >> 98:  Über Schoßhunde und gierige Affen
# []
# >> 99:  Ignaz Semmelweis und die Bekämpfung des Kindbettfiebers
# []
# >> 100:  Der Fall der „Mignonette“ und seine Folgen
# []
# >> 101:  Leon Theremin – Was die Anfänge der elektronischen Musik mit Überwachungstechniken zu tun haben
# []
# >> 102:  Ein Picknick, das die Welt verändert
# []
# >> 103:  Demoskopie – eine kurze Geschichte der (politischen) Meinungsforschung
# []
# >> 104:  Crécy - Chronik eines Versagens
# []
# >> 105:  Skanderbeg – Ein neuer Alexander und seine Bedeutung für die Geschichte Albaniens
# []
# >> 106:  Das Darién-Projekt und seine Folgen
# []
# >> 107:  Eine kurze Geschichte der Guillotine
# []
# >> 108:  Der Paderborner Kaffeelärm
# []
# >> 109:  Der Lotterieaufstand in Albanien
# []
# >> 110:  110, 112, 999, etc.
# []
# >> 111:  Die Anfänge des Esperanto
# []
# >> 112:  Adele Spitzeder und die „Dachauer Bank“
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 113:  Die Hep-Hep-Unruhen von 1819
# []
# >> 114:  Gerhard Zucker und sein Raketentraum
# []
# >> 115:  Eine kurze Geschichte der Hanse
# []
# >> 116:  Über Basken, Wale und ein Massaker auf Island
# []
# >> 117:  Tunix, Tuwat und die Entstehung des Chaos Computer Clubs
# []
# >> 118:  Ein Werwolf in Livland
# []
# >> 119:  Die NS-Thingbewegung – Thingstätten und Thingspiele
# []
# >> 120:  Die Rückkehr des Martin Guerre
# []
# >> 121:  Leopardenmorde und Leopardenmenschen
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 122:  Die Belagerung von Masada
# 	 ERROR: image url download failed
# >> 123:  Christian Gottlieb Prieber – Aussteiger, Renegade und beinahe vergessener Utopist
# []
# >> 124:  Eine kleine Geschichte des Chinese Restaurant Syndroms
# []
# >> 125:  Republik Fredonia
# []
# >> 126:  Für immer im Eis – die Franklin Expedition
# []
# >> 127:  Struensee – Aufstieg und Fall eines Arztes, der (für kurze Zeit) zum dänischen Regenten wurde
# []
# >> 128:  Crash at Crush
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 129:  Die Entdeckung der Dinosaurier
# []
# >> 130:  Alexander von Abonuteichos oder Wie ein Kult entsteht
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 131:  Strathclyde – ein (fast) vergessenes Königreich
# []
# >> 132:  Gesche Gottfried, der Engel von Bremen
# []
# >> 133:  Alexios Komnenos und der Erste Kreuzzug
# []
# >> 134:  Eine kleine Geschichte des Kaiserschnitts anhand der Personen Jacob Nufer, James Barry und Margret Ann Bulkley
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 135:  Adolf Loos
# []
# >> 136:  Der Jüdische Friedhof Währing
# []
# >> 137:  Die Französisch-Britische Union
# 	 ERROR: image url download failed
# >> 138:  Askari und die Kolonialgeschichte des Deutschen Reichs
# []
# >> 139:  Als Voltaire die Lotterie knackte und steinreich wurde
# []
# >> 140:  Eisbrecher für die Diplomatie – das Fußball-Länderspiel Sowjetunion gegen die BRD 1955
# []
# >> 141:  Die kurze Geschichte des Kokovorismus
# []
# >> 142:  Bertha Pappenheim – Gründerin des Jüdischen Frauenbundes und Sozialpionierin
# []
# >> 143:  Über Marsmenschen, Massenpanik und die Entstehung eines Mythos
# []
# >> 144:  Die Spanische Grippe
# []
# >> 145:  Barbara von Cilli oder Wie eine 100 mal wiederholte Lüge zur Wahrheit wird
# []
# >> 146:  Tripel-Allianz-Krieg
# []
# >> 147:  Das Fräulein vom Amt
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 148:  Das Ende der Welt – Friedenskaiser und falsche Friedriche
# 	 ERROR: image url download failed
# >> 149:  Die Kabeljaukriege
# []
# >> 150:  Die Geschichte des Filmstudios Bendestorf
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 151:  Manjirō, der erste Japaner in Amerika
# []
# >> 152:  Ernest Shackleton und die Endurance-Expedition
# []
# >> 153:  Wien-Tour mit Thomas Harbich (#WienFakt)
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 154:  La Maupin, die duellierende Opernsängerin
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 155:  Trofim Lyssenko und der Lyssenkoismus in der Sowjetunion
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 156:  Charles Lindbergh, Alexis Carrel und die Mensch-Maschine
# 	 ERROR: image url download failed
# >> 157:  Salpeter – Aufstieg und Fall einer chemischen Verbindung
# []
# >> 158:  Al-Biruni und die erste Globalgeschichte
# 	 ERROR: image url download failed
# >> 159:  Thorsten Logge über Geschichte und Public History
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 160:  Barbareskenstaaten und die europäischen Seemächte
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 161:  Steamboat Arabia oder Der Schatz im Maisfeld
# []
# >> 162:  Novemberrevolution und die mehrfache Ausrufung der Republik
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 163:  Vernepator Cur - der Hund im Hamsterrad
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 164:  Eine kurze Geschichte des Alkoholkonsums
# 	 ERROR: image url download failed
# >> 165:  Pius IX. und die kurzlebige Römische Republik von 1849
# 	 ERROR: image url download failed
# >> 166:  Siegmund Bosel – die wechselvolle Geschichte eines Inflationskönigs
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 167:  Mary Toft und die Hasen
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 168:  Carl Laemmle und die Anfänge Hollywoods
# ['https://www.zeitsprung.fm/wp-content/cache/podlove
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 186:  Die Redlichen Pioniere von Rochdale und eine kurze Geschichte der Genossenschaften
# 	 ERROR: image url download failed
# >> 187:  Die Wiener Weltausstellung von 1873
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 188:  Martin Couney und die Inkubator-Ausstellungen
# []
# >> 189:  Die Schlacht bei Cannae
# []
# >> 190:  Die Assassinen
# []
# >> 191:  Aethelfled - Warrior Queen of Mercia
# []
# >> 192:  Tiere vor Gericht
# []
# >> 193:  Kanton Übrig – Wie Vorarlberg 1919 nicht der Schweiz beitrat
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 194:  Die Natchez und der französische Kolonialismus in Nordamerika
# 	 ERROR: image url download failed
# >> 195:  Wie Gerta Stern auf der Flucht nach Panama ihren Mann aus dem KZ befreite
# 	 ERROR: image url download failed
# >> 196:  Wie der Panamakanal entstand
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 197:  Das kurzlebige Königreich Finnland – und ein deutscher Adliger auf dem Thron
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 198:  Olga von Kiew oder Mit den Spatzen kam der Tod
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 199:  UC 71 und der U-Boot-Krieg im Ersten Weltkrieg
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 200:  Eine Abrechnung
# []
# >> 201:  Eine kleine Geschichte des Speiseeises
# []
# >> 202:  Über Brunzdoktoren und Uroskopie – die Harnschau in der vormodernen Medizin
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 203:  Bleiben oder gehen? Die Option in Südtirol 1939
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 204:  Obaysch - das viktorianische Nilpferd
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/4c/8180d0b63a96c9ea4e946527bc3460/zs262-die-strawhat-riots_400x.jpg']
# >> 205:  Die Befreiung von Schloss Itter
# []
# >> 206:  Von Verliesen & Drachen - ein 3W6 Crossover
# []
# >> 207:  William Stewart Halsted und die Chirurgie des 19. Jahrhunderts
# []
# >> 208:  Die kleinste Liga der Welt – Eishockey in der DDR
# []
# >> 209:  Cyriacus und die Erfindung der Archäologie
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/4c/8180d0b63a96c9ea4e946527bc3460/zs262-die-strawhat-riots_400x.jpg']
# >> 210:  Der Kunstfälscher Han van Meegeren
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 211:  Griechisches Feuer
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 212:  Eine kleine Geschichte der Sternbilder
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 213:  Tom Morris und eine kleine Geschichte des Golfsports
# []
# >> 214:  Hedy Lamarr – Hollywoodstar und Erfinderin
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 215:  Wojtek, polnischer Soldatenbär
# []
# >> 216:  Napoleon II. – Vom König von Rom zum Herzog von Reichstadt
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 217:  Wie Joseph Haydn den Kopf verlor
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 218:  Die Pazzi-Verschwörung und der Aufstieg der Medici
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 219:  Die Kotze-Affäre
# 	 ERROR: image url download failed
# >> 220:  Eine kurze Geschichte der Rohrpost
# []
# >> 221:  Hans Staden - ein Landsknecht bei den Menschenfressern
# 	 ERROR: image url download failed
# >> 222:  Das Voynich-Manuskript
# []
# >> 223:  Ramen und die Transformation Japans
# []
# >> 224:  Die Balmis-Expedition und eine kurze Geschichte der Pockenimpfung
# []
# >> 225:  Die Rundfahrt der Schlachtfelder
# 	 ERROR: image url download failed
# >> 226:  Der Untergang der Batavia
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/52/7e33cf2385b9ad26e6e83ecea4c279/zs263-lavoisier-und-die-entdeckung-des-sauerstoffs_400x.jpg']
# >> 227:  Die unsterbliche Henrietta Lacks
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/6e/a153853db14e125512d8e11cb1b091/krankenbetten-und-dauerbaeder-ein-zeitsprung-extra-mit-monika-ankele-ueber-psychiatriegeschichte_400x.jpg']
# >> 228:  Berliner Blau – die Erfindung einer Farbe
# []
# >> 229:  Elisabeth Báthory, die (angebliche) Blutgräfin
# 	 ERROR: image url download failed
# >> 230:  Die Tendaguru-Expedition und das größte Dinosaurierskelett der Welt
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 231:  Die Große Enttäuschung von 1844
# []
# >> 232:  Ein Mordfall und das umfangreichste Wörterbuch der englischen Sprache
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 233:  Norton I., Kaiser der USA
# []
# >> 234:  Das bekannteste Parfüm der Welt und seine russische Vorgeschichte
# []
# >> 235:  Die Quarzkrise
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 236:  Monopoly – Die Geschichte eines Brettspiels
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 237:  Friedrich Anton Mesmer und der Animalische Magnetismus
# []
# >> 238:  Kurze Geschichten ausgestorbener Berufe
# []
# >> 239:  Die Zabern-Affäre
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 240:  René Blondlot und die Entdeckung der N-Strahlen
# 	 ERROR: image url download failed
# >> 241:  General Königsmarck und der größte Kunstraub aller Zeiten
# []
# >> 242:  Eine kurze Geschichte der Olympischen Spiele (der Neuzeit)
# []
# >> 243:  Aeneas Coffey und eine kleine Geschichte des irischen Whiskeys
# []
# >> 244:  Die Mühle von Auriol und warum ihre Zerstörung eine Besetzung Frankreichs verhindert hat
# []
# >> 245:  Operation Paul Bunyan
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 246:  John Law und die Mississippi-Blase
# ['https://www.zeitsprung.fm/podlove/image/68747470733a2f2f7777772e7a656974737072756e672e666d2f77702d636f6e74656e742f75706c6f6164732f323032302f31302f5a533236342e6a7067/400/0/0/zs264-seondeok-erste-koenigin-koreas']
# >> 247:  Der Emu Krieg von 1932
# ['https://www.zeitsprung.fm/wp-content/cache/podlove/82/bfe42e93b9fcfbcc185c5ad326f3cb/zs265-syphilis-und-die-tuskegee-syphilis-studie_400x.jpg']
# >> 248:  Der Venustransit von 1761/69 und das erste wissenschaftliche Großprojekt
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-457-42fbaafb536e> in <module>
#      39     # download site
#      40     url = 'https://www.zeitsprung.fm/podcast/zs'+num+'/'
# ---> 41     result = requests.get(url)
#      42     result.encoding = 'utf-8'
#      43     soup = bs4.BeautifulSoup(result.text,"html.parser")
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1904         :return: None.
#    1905         """
# -> 1906         result = _lib.SSL_do_handshake(self._ssl)
#    1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# KeyboardInterrupt:

# %%
num='12'

url = 'https://www.zeitsprung.fm/podcast/zs'+num+'/'
result = requests.get(url)
result.encoding = 'utf-8'
soup = bs4.BeautifulSoup(result.text,"html.parser")


img_str = soup.find_all('img')[15]
a = re.findall(r'src="([^"]*)" style', str(img_str))

soup.find_all('img')[15]

s = 'src="https://www.zeitsprung.fm/wp-content/cache/podlove;" style="width'
result = re.search('asdf=5;(.*)123jasd', s)
print(result.group(1))
# Out:
# <img alt="ZS262: Die Strawhat Riots" src="https://www.zeitsprung.fm/wp-content/cache/podlove/4c/8180d0b63a96c9ea4e946527bc3460/zs262-die-strawhat-riots_400x.jpg" style="width: 20%; vertical-align: top; margin-right: 2%;"/>

# %%
out = str(soup.find_all('img'))
out.find('src="https://www.zeitsprung.fm/wp-content/cache/podlove/')
# Out:
# 5780

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(a[0])
img = Image.open(BytesIO(response.content))
img

# %%
# tag word cloud
from wordcloud import WordCloud, STOPWORDS
import itertools
import matplotlib.pyplot as plt

tag_list = []

for index, row in df.iterrows():
        
    tag_list.append(df["TAGS"][index])
    
tag_string = ''

for n in range(0,len(tag_list)):
    tag_string += tag_list[n]+','
    
tag_string.replace(',',' ')



stopwords = set(STOPWORDS)

zeitsprung_wc = WordCloud(
    background_color='white',
    max_words=2500,
    stopwords=stopwords
)

# generate the word cloud
zeitsprung_wc.generate(tag_string)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(zeitsprung_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
with open("../data/stopwords-de.txt", "r") as f:
    new_stopwords = []
    for line in f.read().splitlines():
        new_stopwords.append(line)

stopwords_ger = set(new_stopwords)


tag_list = []

for index, row in df.iterrows():
        
    tag_list.append(df["DESCRIPTION"][index])
    
tag_string = ''

for n in range(0,len(tag_list)):
    tag_string += tag_list[n]+','
    
tag_string.replace(',',' ')



stopwords = set(STOPWORDS)

zeitsprung_wc = WordCloud(
    background_color='white',
    max_words=2500,
    stopwords=stopwords_ger
)

# generate the word cloud
zeitsprung_wc.generate(tag_string)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

plt.imshow(zeitsprung_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
